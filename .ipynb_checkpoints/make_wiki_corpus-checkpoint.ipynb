# %%
import sys
from gensim.corpora import WikiCorpus

# %%
def make_corpus(in_f, out_f):

    """Convert Wikipedia xml dump file to text corpus"""

    output = open(out_f, 'w')
    wiki = WikiCorpus(in_f)

    i = 0
    for text in wiki.get_texts():
        output.write(bytes(' '.join(text), 'utf-8').decode('utf-8') + '\n')
        i = i + 1
        if (i % 10000 == 0):
            print('Processed ' + str(i) + ' articles')
    output.close()
    print('Processing complete!')

# %% [markdown]
# 02-Jul-2018 14:50

# %%
make_corpus("enwiki-latest-pages-articles-multistream.xml.bz2",
            "wiki_en.txt")
# Out:
# Process InputQueue-8:
# Traceback (most recent call last):
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim-3.4.0-py3.6-linux-x86_64.egg/gensim/utils.py", line 1182, in run
#     wrapped_chunk = [list(chunk)]
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim-3.4.0-py3.6-linux-x86_64.egg/gensim/corpora/wikicorpus.py", line 588, in <genexpr>
#     ((text, self.lemmatize, title, pageid, tokenization_params)
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim-3.4.0-py3.6-linux-x86_64.egg/gensim/corpora/wikicorpus.py", line 364, in extract_pages
#     elem = next(elems)
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim-3.4.0-py3.6-linux-x86_64.egg/gensim/corpora/wikicorpus.py", line 358, in <genexpr>
#     elems = (elem for _, elem in iterparse(f, events=("end",)))
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/xml/etree/ElementTree.py", line 1221, in iterator
#     yield from pullparser.read_events()
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/xml/etree/ElementTree.py", line 1296, in read_events
#     raise event
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/xml/etree/ElementTree.py", line 1268, in feed
#     self._parser.feed(data)
#   File "<string>", line None
# xml.etree.ElementTree.ParseError: syntax error: line 2, column 0
# Process InputQueue-16:
# Traceback (most recent call last):
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim-3.4.0-py3.6-linux-x86_64.egg/gensim/utils.py", line 1182, in run
#     wrapped_chunk = [list(chunk)]
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim-3.4.0-py3.6-linux-x86_64.egg/gensim/corpora/wikicorpus.py", line 588, in <genexpr>
#     ((text, self.lemmatize, title, pageid, tokenization_params)
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim-3.4.0-py3.6-linux-x86_64.egg/gensim/corpora/wikicorpus.py", line 364, in extract_pages
#     elem = next(elems)
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim-3.4.0-py3.6-linux-x86_64.egg/gensim/corpora/wikicorpus.py", line 358, in <genexpr>
#     elems = (elem for _, elem in iterparse(f, events=("end",)))
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/xml/etree/ElementTree.py", line 1221, in iterator
#     yield from pullparser.read_events()
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/xml/etree/ElementTree.py", line 1296, in read_events
#     raise event
#   File "/home/tomoaki/.pyenv/versions/3.6.0/lib/python3.6/xml/etree/ElementTree.py", line 1268, in feed
#     self._parser.feed(data)
#   File "<string>", line None
# xml.etree.ElementTree.ParseError: syntax error: line 2, column 0

# %%
title = []
with open("wiki_en.txt", "r") as f:
    for i in f:
        title.append(i.split()[0])

# %%
title
# Out:
# ['anarchism',
#  'autism',
#  'diffusely',
#  'named',
#  'alabama',
#  'achilles',
#  'abraham',
#  'aristotle',
#  'time',
#  'the',
#  'the',
#  'actresses',
#  'animalia',
#  'international',
#  'giving',
#  'ayn',
#  'alain',
#  'allan',
#  'algeria',
#  'this',
#  'anthropology',
#  'agricultural',
#  'kimiya',
#  'alien',
#  'the',
#  'ascii',
#  'austin',
#  'animation',
#  'apollo',
#  'andre',
#  'the',
#  'afroasiatic',
#  'andorra',
#  'in',
#  'the',
#  'animal',
#  'amphibians',
#  'alaska',
#  'harvesting',
#  'aldous',
#  'ada',
#  'aberdeen',
#  'algae',
#  'analysis',
#  'chemical',
#  'court',
#  'in',
#  'an',
#  'arraignment',
#  'grace',
#  'hearing',
#  'chinese',
#  'zinc',
#  'natural',
#  'the',
#  'in',
#  'apollo',
#  'apollo',
#  'nasa',
#  'modest',
#  'the',
#  'edward',
#  'an',
#  'one',
#  'affirming',
#  'andrei',
#  'sir',
#  'an',
#  'the',
#  'the',
#  'adobe',
#  'fridtjof',
#  'asia',
#  'aruba',
#  'the',
#  'asia',
#  'this',
#  'arthur',
#  'angola',
#  'this',
#  'since',
#  'the',
#  'transport',
#  'the',
#  'the',
#  'albert',
#  'an',
#  'alberta',
#  'john',
#  'actinopterygii',
#  'albert',
#  'afghanistan',
#  'albania',
#  'arabic',
#  'algorithms',
#  'perseid',
#  'mitsuteru',
#  'clockwise',
#  'agnostida',
#  'abortion',
#  'in',
#  'the',
#  'the',
#  'flowchart',
#  'peas',
#  'the',
#  'an',
#  'mouthwash',
#  'alexander',
#  'alfred',
#  'asteroids',
#  'asparagales',
#  'snake',
#  'the',
#  'asterales',
#  'mathilde',
#  'an',
#  'vasil',
#  'aries',
#  'aquarius',
#  'anime',
#  'ankara',
#  'arabic',
#  'sir',
#  'anacondas',
#  'altaic',
#  'austrian',
#  'illustration',
#  'no',
#  'map',
#  'clockwork',
#  'amsterdam',
#  'the',
#  'audi',
#  'nasa',
#  'alfred',
#  'alexander',
#  'anatolia',
#  'apple',
#  'blaeu',
#  'aztlan',
#  'the',
#  'andy',
#  'alp',
#  'the',
#  'was',
#  'pyramids',
#  'analog',
#  'motor',
#  'an',
#  'an',
#  'abba',
#  'an',
#  'altenberg',
#  'the',
#  'alfred',
#  'anna',
#  'alfons',
#  'agnosticism',
#  'argon',
#  'arsenic',
#  'antimony',
#  'actinium',
#  'americium',
#  'astatine',
#  'an',
#  'fields',
#  'aluminium',
#  'advanced',
#  'the',
#  'arne',
#  'the',
#  'an',
#  'andrey',
#  'edvard',
#  'anxiety',
#  'alan',
#  'asociación',
#  'an',
#  'alpha',
#  'alvin',
#  'the',
#  'am',
#  'antigua',
#  'azincourt',
#  'berthold',
#  'asteraceae',
#  'apiaceae',
#  'an',
#  'the',
#  'american',
#  'acute',
#  'ataxia',
#  'abdul',
#  'augusta',
#  'august',
#  'the',
#  'albert',
#  'dame',
#  'the',
#  'applied',
#  'graph',
#  'an',
#  'arecales',
#  'hercule',
#  'jane',
#  'april',
#  'depiction',
#  'aaron',
#  'events',
#  'events',
#  'events',
#  'events',
#  'events',
#  'events',
#  'ball',
#  'achill',
#  'irwin',
#  'in',
#  'events',
#  'anatoly',
#  'the',
#  'auto',
#  'star',
#  'events',
#  'aristophanes',
#  'albert',
#  'the',
#  'an',
#  'aalborg',
#  'aarhus',
#  'the',
#  'abatement',
#  'an',
#  'carrel',
#  'in',
#  'born',
#  'andré',
#  'algorithms',
#  'the',
#  'this',
#  'the',
#  'this',
#  'the',
#  'antisemitism',
#  'azerbaijan',
#  'geography',
#  'azerbaijan',
#  'the',
#  'armenia',
#  'population',
#  'the',
#  'the',
#  'this',
#  'the',
#  'armenia',
#  'american',
#  'this',
#  'politics',
#  'the',
#  'events',
#  'avicenna',
#  'the',
#  'analysis',
#  'abner',
#  'thumb',
#  'amplitude',
#  'augustin',
#  'st',
#  'ardipithecus',
#  'an',
#  'adelaide',
#  'alan',
#  'events',
#  'the',
#  'an',
#  'in',
#  'the',
#  'artificial',
#  'afro',
#  'this',
#  'anaximander',
#  'apl',
#  'an',
#  'example',
#  'aphrodite',
#  'events',
#  'in',
#  'aleister',
#  'afterlife',
#  'illustration',
#  'athena',
#  'the',
#  'athene',
#  'wood',
#  'throughout',
#  'agrarianism',
#  'atomic',
#  'an',
#  'asa',
#  'artificial',
#  'atomic',
#  'american',
#  'in',
#  'alternate',
#  'the',
#  'the',
#  'alan',
#  'the',
#  'the',
#  'johann',
#  'actaeon',
#  'anglicanism',
#  'athens',
#  'anguilla',
#  'this',
#  'ashmore',
#  'acoustic',
#  'alexander',
#  'ashoka',
#  'the',
#  'ada',
#  'alfonso',
#  'arianism',
#  'events',
#  'denarius',
#  'events',
#  'the',
#  'events',
#  'an',
#  'wmap',
#  'visual',
#  'world',
#  'trial',
#  'augustus',
#  'the',
#  'transport',
#  'physiographic',
#  'the',
#  'apocryphal',
#  'satellite',
#  'alfred',
#  'ames',
#  'abalone',
#  'nieśwież',
#  'the',
#  'abduction',
#  'maderturm',
#  'arminianism',
#  'the',
#  'in',
#  'an',
#  'sénanque',
#  'the',
#  'in',
#  'casa',
#  'the',
#  'casa',
#  'illustration',
#  'kim',
#  'this',
#  'events',
#  'events',
#  'in',
#  'the',
#  'the',
#  'apple',
#  'apatosaurus',
#  'allosaurus',
#  'the',
#  'atanasoff',
#  'the',
#  'ancylopoda',
#  'anchor',
#  'anbar',
#  'general',
#  'an',
#  'anadyr',
#  'andré',
#  'ammonia',
#  'amethyst',
#  'albertosaurus',
#  'an',
#  'majolica',
#  'aurelius',
#  'ambracia',
#  'pendants',
#  'illustration',
#  'de',
#  'an',
#  'the',
#  'alder',
#  'amos',
#  'arachnophobia',
#  'bast',
#  'ahab',
#  'asic',
#  'dasyproctidae',
#  'algol',
#  'amazing',
#  'aol',
#  'carinthia',
#  'av',
#  'alcuin',
#  'saint',
#  'primary',
#  'events',
#  'events',
#  'zero',
#  'in',
#  'structures',
#  'animism',
#  'museo',
#  'adrian',
#  'the',
#  'abbotsford',
#  'abraham',
#  'abraxas',
#  'absalom',
#  'abydos',
#  'abydos',
#  'abydos',
#  'events',
#  'acacia',
#  'acapulco',
#  'events',
#  'alan',
#  'apl',
#  'algol',
#  'awk',
#  'yggdrasil',
#  'the',
#  'an',
#  'meadow',
#  'hœnir',
#  'the',
#  'alanus',
#  'area',
#  'nyse',
#  'events',
#  'it',
#  'alfred',
#  'the',
#  'events',
#  'events',
#  'events',
#  'the',
#  'lory',
#  'albert',
#  'albert',
#  'albert',
#  'albert',
#  'albert',
#  'albert',
#  'cardinal',
#  'albert',
#  'events',
#  'aachen',
#  'agate',
#  'aspirin',
#  'illustration',
#  'ahmed',
#  'ahmed',
#  'ahmed',
#  'the',
#  'the',
#  'acupuncture',
#  'adder',
#  'aeneas',
#  'events',
#  'amaranthus',
#  'agapanthus',
#  'the',
#  'aga',
#  'sir',
#  'alexander',
#  'this',
#  'agesilaus',
#  'agis',
#  'antonio',
#  'agnes',
#  'agrippina',
#  'agrippina',
#  'american',
#  'ahenobarbus',
#  'ahmad',
#  'arthur',
#  'ailanthus',
#  'overview',
#  'the',
#  'ajax',
#  'ajax',
#  'ajax',
#  'alaric',
#  'anastasius',
#  'albertus',
#  'alboin',
#  'afonso',
#  'alcaeus',
#  'herm',
#  'in',
#  'alcidamas',
#  'thumb',
#  'ealdred',
#  'alexander',
#  'alexander',
#  'alexander',
#  'illustration',
#  'alexander',
#  'alexander',
#  'alexander',
#  'alexander',
#  'alexander',
#  'alexander',
#  'opening',
#  'severus',
#  'alexander',
#  'alexander',
#  'alexander',
#  'alexander',
#  'alexander',
#  'to',
#  'the',
#  'alexios',
#  'alexis',
#  'alexios',
#  'alexios',
#  'alexios',
#  'alexei',
#  'andrew',
#  'andrew',
#  'aleksandr',
#  'aberdeen',
#  'events',
#  'events',
#  'the',
#  'aquaculture',
#  'this',
#  'hymn',
#  'the',
#  'events',
#  'no',
#  'terracotta',
#  'alger',
#  'algiers',
#  'hasan',
#  'alessandro',
#  'the',
#  'succulent',
#  'alyattes',
#  'the',
#  'alypius',
#  'amalasuntha',
#  'amalric',
#  'afonso',
#  'afonso',
#  'afonso',
#  'afonso',
#  'afonso',
#  'afonso',
#  'there',
#  'alfonso',
#  'cover',
#  'alfonso',
#  'alfonso',
#  'alfonso',
#  'amaryllis',
#  'his',
#  'alfonso',
#  'amasis',
#  'alfonso',
#  'amathus',
#  'alphons',
#  'alfonso',
#  'amati',
#  'wounded',
#  'ambergris',
#  'statue',
#  'thumb',
#  'topography',
#  'alredus',
#  'events',
#  'events',
#  'autpert',
#  'abū',
#  'ambrose',
#  'ambrosians',
#  'ambrosiaster',
#  'ambrosius',
#  'an',
#  'ammonius',
#  'ammonius',
#  'the',
#  'amphipolis',
#  'in',
#  'amyntas',
#  'amyntas',
#  'th',
#  'anah',
#  'tibetan',
#  'anaxagoras',
#  'anaxarchus',
#  'ancyra',
#  'anaximenes',
#  'anastasius',
#  'anaximenes',
#  'ancus',
#  'detailed',
#  'supplementum',
#  'andocides',
#  'triumphus',
#  'andrew',
#  'allan',
#  'andré',
#  'coin',
#  'andronikos',
#  'andronikos',
#  'andronikos',
#  'the',
#  'andronicus',
#  'andronicus',
#  'ammianus',
#  'alice',
#  'apollo',
#  'apollo',
#  'apollo',
#  'arthritis',
#  'events',
#  'acetylene',
#  'alfred',
#  'events',
#  'arabic',
#  'events',
#  'abm',
#  'apuleius',
#  'alexander',
#  'ground',
#  'events',
#  'events',
#  'the',
#  'atp',
#  'adenosine',
#  'in',
#  'an',
#  'arnold',
#  'asa',
#  'map',
#  'amway',
#  'adam',
#  'antoine',
#  'adolph',
#  'events',
#  'events',
#  'amitabh',
#  'in',
#  'simplified',
#  'in',
#  'pearl',
#  'diamond',
#  'coin',
#  'aerial',
#  'baron',
#  'archimedes',
#  'alternative',
#  'in',
#  'set',
#  'composite',
#  'right',
#  'on',
#  'arizona',
#  'events',
#  'astoria',
#  'alarums',
#  'alfred',
#  'amalric',
#  'amalric',
#  'aimery',
#  'anthemius',
#  'absalon',
#  'versailles',
#  'commune',
#  'alfonso',
#  'ambroise',
#  'art',
#  'oldskool',
#  'alexius',
#  'english',
#  'boston',
#  'the',
#  'acquire',
#  'australian',
#  'american',
#  'the',
#  'an',
#  'galápagos',
#  'digital',
#  'an',
#  'ampicillin',
#  'annealing',
#  'alt',
#  'an',
#  'an',
#  'antwerp',
#  'aquila',
#  'al',
#  'alessandro',
#  'the',
#  'perseus',
#  'antlia',
#  'ara',
#  'auriga',
#  'arkansas',
#  'an',
#  'apus',
#  'abadan',
#  'attorney',
#  'sir',
#  'national',
#  'approximants',
#  'john',
#  'the',
#  'polet',
#  'the',
#  'the',
#  'large',
#  'aotus',
#  'ally',
#  'andreas',
#  'the',
#  'adobe',
#  'the',
#  'portrait',
#  'asteroid',
#  'absolute',
#  'apollo',
#  'apollo',
#  'apollo',
#  'apollo',
#  'apollo',
#  'apollo',
#  'apollo',
#  'john',
#  'events',
#  'sir',
#  'alpha',
#  'the',
#  'absorption',
#  'the',
#  'abel',
#  'events',
#  'asp',
#  'this',
#  'austin',
#  'the',
#  'asl',
#  'auschwitz',
#  'archery',
#  'hugo',
#  'the',
#  'atomic',
#  'the',
#  'arbor',
#  'sir',
#  'andré',
#  'the',
#  'atle',
#  'aeschylus',
#  'the',
#  'crandall',
#  'sir',
#  'ambient',
#  'anne',
#  'saint',
#  'french',
#  'delian',
#  'august',
#  'radar',
#  'ares',
#  'alexander',
#  'alcoholics',
#  'this',
#  'in',
#  'advance',
#  'an',
#  'amerigo',
#  'aristide',
#  'antonio',
#  'françois',
#  'ann',
#  'the',
#  'aircraft',
#  'the',
#  'johann',
#  'the',
#  'fire',
#  'space',
#  'the',
#  'acts',
#  'assyria',
#  'abijah',
#  'ark',
#  'aphasia',
#  'the',
#  'abimelech',
#  'andrew',
#  'applesoft',
#  'asterix',
#  'the',
#  'the',
#  'mjölnir',
#  'an',
#  'adalbert',
#  'ælfheah',
#  'in',
#  'in',
#  'aix',
#  'appletalk',
#  'the',
#  'the',
#  'animation',
#  'acyclic',
#  'astrology',
#  'abyssinia',
#  'in',
#  'angela',
#  'an',
#  'the',
#  'aesthetics',
#  'joshua',
#  'map',
#  'the',
#  'arthur',
#  'these',
#  'the',
#  'the',
#  'the',
#  'aaliyah',
#  'armour',
#  'mark',
#  'anton',
#  'all',
#  'african',
#  'the',
#  'afrikaans',
#  'in',
#  'abc',
#  'an',
#  'abcd',
#  'in',
#  'arsenal',
#  'apple',
#  'ahmad',
#  'athanasius',
#  'saint',
#  'arcadius',
#  'arabs',
#  'nine',
#  'antisemitism',
#  'events',
#  'concept',
#  'events',
#  'events',
#  'events',
#  'the',
#  'abdulaziz',
#  'aage',
#  'cartesian',
#  'countries',
#  'auf',
#  'the',
#  'anglo',
#  'folklore',
#  'sid',
#  'abu',
#  'the',
#  'additive',
#  'charles',
#  'the',
#  'typical',
#  'events',
#  'paul',
#  'for',
#  'ælle',
#  'atari',
#  'afghan',
#  'acadia',
#  'fingerpicking',
#  'baldassarre',
#  'portrait',
#  'the',
#  'the',
#  'opium',
#  'abiotic',
#  'the',
#  'episcopal',
#  'ascorbic',
#  'amsterdamsche',
#  'sir',
#  'an',
#  'events',
#  'alexis',
#  'decommissioned',
#  'two',
#  'eland',
#  'soviet',
#  'alkmaar',
#  'the',
#  'american',
#  'arāmāyā',
#  'titus',
#  'atomic',
#  'arthur',
#  'anton',
#  'anita',
#  'the',
#  'an',
#  'the',
#  'audio',
#  'evolution',
#  'events',
#  'loreto',
#  'alfonso',
#  'in',
#  'acn',
#  'an',
#  'the',
#  'the',
#  'rise',
#  'james',
#  'antipope',
#  'the',
#  'adventism',
#  'the',
#  'albion',
#  'the',
#  'in',
#  'the',
#  'associazione',
#  'the',
#  'each',
#  'pietro',
#  'aston',
#  'albert',
#  'alf',
#  'abdul',
#  'andhra',
#  'the',
#  'andreas',
#  'aalen',
#  'aloysius',
#  'aedile',
#  'american',
#  'antidepressants',
#  'two',
#  'was',
#  'diagram',
#  'early',
#  'events',
#  'nitrocellulose',
#  'sir',
#  'ardal',
#  'advanced',
#  'albrecht',
#  'australian',
#  'aon',
#  'sketch',
#  'gas',
#  'cappella',
#  'john',
#  'athanasius',
#  'alicante',
#  'events',
#  'ann',
#  'muhi',
#  'alexander',
#  'page',
#  'audio',
#  'minute',
#  'alberto',
#  'an',
#  'albrecht',
#  'the',
#  'in',
#  'removal',
#  'anton',
#  'action',
#  'aw',
#  'apoptosis',
#  'appomattox',
#  'an',
#  'aarau',
#  'the',
#  'aba',
#  'the',
#  'the',
#  'abacá',
#  'apollyon',
#  'abadeh',
#  'the',
#  'abakan',
#  ...]
